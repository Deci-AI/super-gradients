# %% [markdown]
# # Convert SG Models to CoreML

# %% [markdown]
# Let's install the minimal dependencies for getting started.<br>
# Those will be 'super-gradients' and 'coremltools'.<br>
# If you are using Colab, please restart the kernel after they are installed and only then continue.

# %%
# !python3 -m pip install super-gradients coremltools onnx==1.13.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: super-gradients in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: coremltools in /usr/local/lib/python3.10/dist-packages (6.3.0)
# Requirement already satisfied: onnx==1.13.0 in /usr/local/lib/python3.10/dist-packages (1.13.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from onnx==1.13.0) (1.22.4)
# Requirement already satisfied: protobuf<4,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx==1.13.0) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx==1.13.0) (4.5.0)
# Requirement already satisfied: torch<1.14,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.13.1)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (4.65.0)
# Requirement already satisfied: boto3>=1.17.15 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.26.133)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (4.3.3)
# Requirement already satisfied: Deprecated>=1.2.11 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.2.13)
# Requirement already satisfied: opencv-python>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (4.7.0.72)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.10.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (3.7.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (5.9.5)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (2.12.2)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (67.7.2)
# Requirement already satisfied: coverage~=5.3.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (5.3.1)
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (0.14.1)
# Requirement already satisfied: sphinx~=4.0.2 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (4.0.3)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.2.0)
# Requirement already satisfied: torchmetrics==0.8 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (0.8.0)
# Requirement already satisfied: pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (9.5.0)
# Requirement already satisfied: hydra-core>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.3.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from super-gradients) (2.3.0)
# Requirement already satisfied: onnxruntime==1.13.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.13.1)
# Requirement already satisfied: pip-tools>=6.12.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (6.13.0)
# Requirement already satisfied: pyparsing==2.4.5 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (2.4.5)
# Requirement already satisfied: einops==0.3.2 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (0.3.2)
# Requirement already satisfied: pycocotools==2.0.4 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (2.0.4)
# Requirement already satisfied: treelib==1.6.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.6.1)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.1.0)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (23.1)
# Requirement already satisfied: wheel>=0.38.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (0.40.0)
# Requirement already satisfied: pygments>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (2.14.0)
# Requirement already satisfied: stringcase>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (1.2.0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from super-gradients) (3.0.0)
# Requirement already satisfied: json-tricks==3.16.1 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (3.16.1)
# Requirement already satisfied: onnx-simplifier<1.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from super-gradients) (0.4.28)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.13.1->super-gradients) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.13.1->super-gradients) (23.3.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.13.1->super-gradients) (1.11.1)
# Requirement already satisfied: pyDeprecate==0.3.* in /usr/local/lib/python3.10/dist-packages (from torchmetrics==0.8->super-gradients) (0.3.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from treelib==1.6.1->super-gradients) (0.18.3)
# Requirement already satisfied: botocore<1.30.0,>=1.29.133 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.17.15->super-gradients) (1.29.133)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.17.15->super-gradients) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.17.15->super-gradients) (0.6.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated>=1.2.11->super-gradients) (1.14.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.2.0->super-gradients) (4.9.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.2.0->super-gradients) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.2.0->super-gradients) (0.19.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->super-gradients) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->super-gradients) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->super-gradients) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->super-gradients) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->super-gradients) (2.8.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf->super-gradients) (6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from onnx-simplifier<1.0,>=0.3.6->super-gradients) (13.3.4)
# Requirement already satisfied: build in /usr/local/lib/python3.10/dist-packages (from pip-tools>=6.12.1->super-gradients) (0.10.0)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.10/dist-packages (from pip-tools>=6.12.1->super-gradients) (8.1.3)
# Requirement already satisfied: pip>=22.2 in /usr/local/lib/python3.10/dist-packages (from pip-tools>=6.12.1->super-gradients) (23.1.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (2.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (1.0.3)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (3.1.2)
# Requirement already satisfied: docutils<0.18,>=0.14 in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (0.16)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (2.12.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx~=4.0.2->super-gradients) (2.27.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->super-gradients) (2.3.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<1.14,>=1.9.0->super-gradients) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch<1.14,>=1.9.0->super-gradients) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch<1.14,>=1.9.0->super-gradients) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<1.14,>=1.9.0->super-gradients) (11.7.99)
# Requirement already satisfied: sphinxcontrib-jquery!=3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->super-gradients) (4.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime==1.13.1->super-gradients) (1.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.30.0,>=1.29.133->boto3>=1.17.15->super-gradients) (1.26.15)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->super-gradients) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx~=4.0.2->super-gradients) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients) (3.4)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build->pip-tools>=6.12.1->super-gradients) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build->pip-tools>=6.12.1->super-gradients) (2.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime==1.13.1->super-gradients) (10.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->onnx-simplifier<1.0,>=0.3.6->super-gradients) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->onnx-simplifier<1.0,>=0.3.6->super-gradients) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->super-gradients) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->super-gradients) (3.2.2)

# %% [markdown]
# ## Restart the notebook, and then continue;

# %% [markdown]
# Let's import everything we need, including super gradients and coremltools.

# %%
from typing import List
import os

import coremltools as ct
from super_gradients.common.object_names import Models
from super_gradients.training import models
import torch
# Out:
# WARNING:coremltools:scikit-learn version 1.2.2 is not supported. Minimum required version: 0.17. Maximum required version: 1.1.2. Disabling scikit-learn conversion API.
# WARNING:coremltools:XGBoost version 1.7.5 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# [2023-05-15 10:56:48] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# The console stream is logged into /root/sg_logs/console.log
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# [2023-05-15 10:57:00] WARNING - __init__.py - Failed to import pytorch_quantization
# [2023-05-15 10:57:00] WARNING - calibrator.py - Failed to import pytorch_quantization
# [2023-05-15 10:57:00] WARNING - export.py - Failed to import pytorch_quantization
# [2023-05-15 10:57:00] WARNING - selective_quantization_utils.py - Failed to import pytorch_quantization

# %% [markdown]
# ## Load any SG model

# %% [markdown]
# For this tutorial we will use the YOLO-NAS-S model.<br>
# We will load the pretrained version of Deci's YOLO NAS S model and convert the graph representation from PyTorch to CoreML.<br>
# We also must define an example input - It is required when exporting torch models.<br>

# %%
sg_torch_model = models.get(Models.YOLO_NAS_S, pretrained_weights="coco")
example_inputs = [torch.rand(1,3,640,640).cpu()]
sg_torch_model.prep_model_for_conversion(input_size=example_inputs[0].shape)
print('Loaded successfully')
# Out:
# [2023-05-15 10:57:00] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.

# %% [markdown]
# Let's define the conversion method, that receives an SG nn.Module together with eample inputs and target path, converts the model representation to CoreML, and saves the compiled checkpoint to the specified path.

# %%
def convert_sg_model_to_coreml(sg_model: torch.nn.Module,
                               example_inputs: List[torch.nn.Module],
                               output_path: os.PathLike = None,
                               export_as_ml_program=False):
    """
    Converts a given SG model to CoreML mlprogram or package.

    @param sg_model: A super-gradients nn.Module to compile
    @param example_inputs: A list of input tensors to feed the model, required to trace with torch.jit.
    @param output_path: The path to save the compiled CoreML model into.
    @param export_as_ml_program: Whether to convert to the new program format (better) or legacy coreml proto file (Supports more iOS versions and devices, but this format will be deprecated at some point).
    """
    print('Building model...')
    print(sg_model)
    print('Model child nodes:')
    print(next(sg_model.named_children()))

    # Set the model in evaluation mode.
    sg_model.eval()
    print('Creating torch jit trace...')
    traced_model = torch.jit.trace(sg_model, example_inputs)
    print('Tracing the model with the provided inputs...')
    out = traced_model(*example_inputs)
    print('Inferred output shapes:', [o.shape for o in out])

    print('Converting to CoreML...')
    if not output_path:
        output_path = os.sep.join([os.getcwd(), sg_model.__class__.__name__.lower()])
        output_path += 'mlpackage' if export_as_ml_program else '.mlmodel'

    if export_as_ml_program:
        coreml_model = ct.convert(
            traced_model,
            convert_to="mlprogram",
            inputs=[ct.ImageType(name=f"x_{i+1}",
                                 shape=_.shape) for i, _ in enumerate(example_inputs)]
        )
    else:
        coreml_model = ct.convert(
            traced_model,
            inputs=[ct.ImageType(name=f"x_{i+1}",
                                 shape=_.shape) for i, _ in enumerate(example_inputs)]
        )

    spec = coreml_model.get_spec()
    print(spec.description)

    # Changing the input names:
    #   In CoreML, the input name is compiled into classes (named keyword argument in predict).
    #   We want to re-use the same names among different models to make research easier.
    #   We normalize the inputs names to be x_1, x_2, etc.
    for i, _input in enumerate(spec.description.input):
        new_input_name = "x_" + str(i + 1)
        print(f'Renaming input {_input.name} to {new_input_name}')
        ct.utils.rename_feature(spec, _input.name, new_input_name)

    # Re-Initializing the model with the new spec
    coreml_model = ct.models.MLModel(spec, weights_dir=coreml_model.weights_dir)

    # Saving the model
    coreml_model.save(output_path)
    print('CoreML model successfully save to ', os.path.abspath(output_path))

# %% [markdown]
# ## Convert to CoreML

# %% [markdown]
# After the model loaded successfully, we will define a target path to store the compiled model into.<br>
# In this case, our file is named "deci-yolo-nas-s.mlmodel" in the current working directory ('/content' in google colab).

# %%
output_path = "deci-yolo-nas-s.mlmodel"
convert_sg_model_to_coreml(sg_model=sg_torch_model,
                           output_path=output_path,
                           example_inputs=example_inputs,
                           export_as_ml_program=False)
# Out:
# Loaded successfully
# Building model...
# YoloNAS_S(
#   (backbone): NStageBackbone(
#     (stem): YoloNASStem(
#       (conv): QARepVGGBlock(
#         (nonlinearity): ReLU(inplace=True)
#         (se): Identity()
#         (post_bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (rbr_reparam): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (stage1): YoloNASStage(
#       (downsample): QARepVGGBlock(
#         (nonlinearity): ReLU(inplace=True)
#         (se): Identity()
#         (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (rbr_reparam): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(64, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#     (stage2): YoloNASStage(
#       (downsample): QARepVGGBlock(
#         (nonlinearity): ReLU(inplace=True)
#         (se): Identity()
#         (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (rbr_reparam): Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (2): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#     (stage3): YoloNASStage(
#       (downsample): QARepVGGBlock(
#         (nonlinearity): ReLU(inplace=True)
#         (se): Identity()
#         (post_bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (rbr_reparam): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (2): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (3): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (4): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#     (stage4): YoloNASStage(
#       (downsample): QARepVGGBlock(
#         (nonlinearity): ReLU(inplace=True)
#         (se): Identity()
#         (post_bn): BatchNorm2d(768, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (rbr_reparam): Conv2d(384, 768, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(768, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#     (context_module): SPP(
#       (cv1): Conv(
#         (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1536, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(768, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#         (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (neck): YoloNASPANNeckWithC2(
#     (neck1): YoloNASUpStage(
#       (reduce_skip1): Conv(
#         (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (reduce_skip2): Conv(
#         (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv): Conv(
#         (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (upsample): ConvTranspose2d(192, 192, kernel_size=(2, 2), stride=(2, 2))
#       (downsample): Conv(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (reduce_after_concat): Conv(
#         (conv): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#     (neck2): YoloNASUpStage(
#       (reduce_skip1): Conv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (reduce_skip2): Conv(
#         (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv): Conv(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (upsample): ConvTranspose2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#       (downsample): Conv(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (reduce_after_concat): Conv(
#         (conv): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (cv2): QARepVGGBlock(
#               (nonlinearity): ReLU(inplace=True)
#               (se): Identity()
#               (post_bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (rbr_reparam): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#     (neck3): YoloNASDownStage(
#       (conv): Conv(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#     (neck4): YoloNASDownStage(
#       (conv): Conv(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (blocks): YoloNASCSPLayer(
#         (conv1): Conv(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv2): Conv(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (conv3): Conv(
#           (conv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (bottlenecks): SequentialWithIntermediates(
#           (0): YoloNASBottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (shortcut): Residual()
#           )
#           (1): YoloNASBottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (shortcut): Residual()
#           )
#         )
#       )
#     )
#   )
#   (heads): NDFLHeads(
#     (head1): YoloNASDFLHead(
#       (stem): ConvBNReLU(
#         (seq): Sequential(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#       (cls_convs): Sequential(
#         (0): ConvBNReLU(
#           (seq): Sequential(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (reg_convs): Sequential(
#         (0): ConvBNReLU(
#           (seq): Sequential(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (cls_pred): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1))
#       (reg_pred): Conv2d(64, 68, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (head2): YoloNASDFLHead(
#       (stem): ConvBNReLU(
#         (seq): Sequential(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#       (cls_convs): Sequential(
#         (0): ConvBNReLU(
#           (seq): Sequential(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (reg_convs): Sequential(
#         (0): ConvBNReLU(
#           (seq): Sequential(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (cls_pred): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#       (reg_pred): Conv2d(128, 68, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (head3): YoloNASDFLHead(
#       (stem): ConvBNReLU(
#         (seq): Sequential(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#       (cls_convs): Sequential(
#         (0): ConvBNReLU(
#           (seq): Sequential(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (reg_convs): Sequential(
#         (0): ConvBNReLU(
#           (seq): Sequential(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (cls_pred): Conv2d(256, 80, kernel_size=(1, 1), stride=(1, 1))
#       (reg_pred): Conv2d(256, 68, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# Model child nodes:
# ('backbone', NStageBackbone(
#   (stem): YoloNASStem(
#     (conv): QARepVGGBlock(
#       (nonlinearity): ReLU(inplace=True)
#       (se): Identity()
#       (post_bn): BatchNorm2d(48, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (rbr_reparam): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#   )
#   (stage1): YoloNASStage(
#     (downsample): QARepVGGBlock(
#       (nonlinearity): ReLU(inplace=True)
#       (se): Identity()
#       (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (rbr_reparam): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (blocks): YoloNASCSPLayer(
#       (conv1): Conv(
#         (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv3): Conv(
#         (conv): Conv2d(64, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (bottlenecks): SequentialWithIntermediates(
#         (0): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (1): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#       )
#     )
#   )
#   (stage2): YoloNASStage(
#     (downsample): QARepVGGBlock(
#       (nonlinearity): ReLU(inplace=True)
#       (se): Identity()
#       (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (rbr_reparam): Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (blocks): YoloNASCSPLayer(
#       (conv1): Conv(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv3): Conv(
#         (conv): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (bottlenecks): SequentialWithIntermediates(
#         (0): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (1): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (2): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#       )
#     )
#   )
#   (stage3): YoloNASStage(
#     (downsample): QARepVGGBlock(
#       (nonlinearity): ReLU(inplace=True)
#       (se): Identity()
#       (post_bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (rbr_reparam): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (blocks): YoloNASCSPLayer(
#       (conv1): Conv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv3): Conv(
#         (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (bottlenecks): SequentialWithIntermediates(
#         (0): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (1): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (2): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (3): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (4): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#       )
#     )
#   )
#   (stage4): YoloNASStage(
#     (downsample): QARepVGGBlock(
#       (nonlinearity): ReLU(inplace=True)
#       (se): Identity()
#       (post_bn): BatchNorm2d(768, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (rbr_reparam): Conv2d(384, 768, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (blocks): YoloNASCSPLayer(
#       (conv1): Conv(
#         (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (conv3): Conv(
#         (conv): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(768, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (bottlenecks): SequentialWithIntermediates(
#         (0): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#         (1): YoloNASBottleneck(
#           (cv1): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (cv2): QARepVGGBlock(
#             (nonlinearity): ReLU(inplace=True)
#             (se): Identity()
#             (post_bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (rbr_reparam): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (shortcut): Residual()
#         )
#       )
#     )
#   )
#   (context_module): SPP(
#     (cv1): Conv(
#       (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(1536, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#     )
#     (m): ModuleList(
#       (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#       (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#     )
#   )
# ))
# Creating torch jit trace...
# Tracing the model with the provided inputs...
# Inferred output shapes: [torch.Size([1, 8400, 4]), torch.Size([1, 8400, 80])]
# Converting to CoreML...
# [2023-05-15 10:57:17] WARNING - torchir_passes.py - Tuple detected at graph output. This will be flattened in the converted model.
# [2023-05-15 10:57:17] INFO - converter.py - Converting graph.
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stem.conv.rbr_reparam.bias' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stem.conv.rbr_reparam.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stem.conv.post_bn.running_var' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stem.conv.post_bn.running_mean' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stem.conv.post_bn.bias' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stem.conv.post_bn.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.downsample.rbr_reparam.bias' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.downsample.rbr_reparam.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.downsample.post_bn.running_var' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.downsample.post_bn.running_mean' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.downsample.post_bn.bias' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.downsample.post_bn.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.conv1.conv.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.conv1.bn.running_var' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.conv1.bn.running_mean' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.conv1.bn.bias' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.conv1.bn.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.alpha' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.cv1.rbr_reparam.bias' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.cv1.rbr_reparam.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.cv1.post_bn.running_var' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.cv1.post_bn.running_mean' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.cv1.post_bn.bias' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.cv1.post_bn.weight' of type const
# [2023-05-15 10:57:17] INFO - builder.py - Adding op 'backbone.stage1.blocks.bottlenecks.0.cv2.rbr_reparam.bias' of type const
# ...
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.3.cv1.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.3.cv1.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.3.cv1.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.3.cv1.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.3.cv1.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.3.cv1.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv2.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv2.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv2.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv2.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv2.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv2.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv1.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv1.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv1.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv1.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv1.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.2.cv1.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv2.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv2.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv2.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv2.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv2.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv2.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv1.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv1.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv1.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv1.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv1.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.1.cv1.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv2.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv2.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv2.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv2.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv2.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv2.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv1.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv1.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv1.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv1.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv1.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.bottlenecks.0.cv1.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.conv1.bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.conv1.bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.conv1.bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.conv1.bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.blocks.conv1.conv.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.downsample.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.downsample.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.downsample.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.downsample.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.downsample.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage3.downsample.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv3.bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv3.bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv3.bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv3.bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv3.conv.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv2.bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv2.bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv2.bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv2.bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.conv2.conv.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv2.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv2.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv2.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv2.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv2.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv2.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv1.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv1.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv1.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv1.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv1.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.2.cv1.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv2.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv2.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv2.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv2.post_bn.running_var" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv2.rbr_reparam.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv2.rbr_reparam.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv1.post_bn.weight" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv1.post_bn.bias" (type: const)
# [2023-05-15 10:57:32] INFO - dead_code_elimination.py - Removing op "backbone.stage2.blocks.bottlenecks.1.cv1.post_bn.running_mean" (type: const)
# [2023-05-15 10:57:34] INFO - op_mapping.py - added const backbone.stage3.blocks.bottlenecks.2.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# [2023-05-15 10:57:34] INFO - op_mapping.py - added const backbone.stage3.blocks.bottlenecks.3.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops:  29%|██▉       | 281/964 [00:00<00:01, 492.52 ops/s] [2023-05-15 10:57:34] INFO - op_mapping.py - added const backbone.stage3.blocks.bottlenecks.4.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# [2023-05-15 10:57:35] INFO - op_mapping.py - added const backbone.stage4.blocks.bottlenecks.0.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops:  37%|███▋      | 355/964 [00:01<00:03, 170.54 ops/s][2023-05-15 10:57:35] INFO - op_mapping.py - added const backbone.stage4.blocks.bottlenecks.1.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops:  50%|████▉     | 480/964 [00:02<00:03, 137.07 ops/s][2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck1.blocks.bottlenecks.0.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# [2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck1.blocks.bottlenecks.1.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops:  54%|█████▎    | 517/964 [00:02<00:02, 166.07 ops/s][2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck2.blocks.bottlenecks.0.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# [2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck2.blocks.bottlenecks.1.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops:  65%|██████▌   | 627/964 [00:02<00:01, 310.25 ops/s][2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck3.blocks.bottlenecks.0.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# [2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck3.blocks.bottlenecks.1.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops:  76%|███████▌  | 734/964 [00:03<00:00, 391.96 ops/s][2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck4.blocks.bottlenecks.0.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# [2023-05-15 10:57:36] INFO - op_mapping.py - added const neck.neck4.blocks.bottlenecks.1.alpha for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops:  98%|█████████▊| 946/964 [00:03<00:00, 321.76 ops/s][2023-05-15 10:57:37] INFO - op_mapping.py - added const points for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# [2023-05-15 10:57:37] WARNING - op_mapping.py - Const points was already added.
# [2023-05-15 10:57:37] INFO - op_mapping.py - added const stride_tensor for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7fdf3c735d80>
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 964/964 [00:03<00:00, 255.28 ops/s]
# input {
#   name: "x_1"
#   type {
#     imageType {
#       width: 640
#       height: 640
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "var_1886"
#   type {
#     multiArrayType {
#       dataType: FLOAT32
#     }
#   }
# }
# output {
#   name: "var_1877"
#   type {
#     multiArrayType {
#       dataType: FLOAT32
#     }
#   }
# }
# metadata {
#   userDefined {
#     key: "com.github.apple.coremltools.source"
#     value: "torch==1.13.1+cu117"
#   }
#   userDefined {
#     key: "com.github.apple.coremltools.version"
#     value: "6.3.0"
#   }
# }
#
# Renaming input x_1 to x_1

# %% [markdown]
# Let's look at our CoreML model:

# %%
ls -alh /content/
# Out:
# total 47M
# drwxr-xr-x 1 root root 4.0K May 15 10:57 ./
# drwxr-xr-x 1 root root 4.0K May 15 10:04 ../
# drwxr-xr-x 4 root root 4.0K May 11 16:34 .config/
# -rw-r--r-- 1 root root  47M May 15 10:57 deci-yolo-nas-s.mlmodel
# drwxr-xr-x 2 root root 4.0K May 15 10:25 .ipynb_checkpoints/
# drwxr-xr-x 1 root root 4.0K May 11 16:35 sample_data/

# %% [markdown]
# Cool! Our YOLO-NAS-S model weights 47MB in Float32 (full) percision.<br> It can definitely fit into an iOS app or OS X Desktop application.

# %% [markdown]
# ## Visualize the CoreML model with Netron

# %% [markdown]
# If the notebook runs on localhost, you can visualize the exported CoreML model to Netron.<br>
# If you use Google Colab, you can download the model in the directory explorer on the left, and upload it to https://netron.app/ instead of self-installing.

# %%
# !python3 -m pip install netron
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: netron in /usr/local/lib/python3.10/dist-packages (6.8.8)

# %%
import IPython
import threading
import time
import os

def display_netron(path):
    os.system(f'netron {path}')
    
thread = threading.Thread(target=display_netron, args=(output_path,))
thread.start()

time.sleep(1)
display(IPython.display.IFrame(f"http://localhost:8080", width=1000, height=1000))
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="http://localhost:8080"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
