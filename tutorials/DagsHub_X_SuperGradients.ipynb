# %% [markdown]
# <center><a href="https://dagshub.com/user/sign_up?utm_source=github&utm_medium=experiment_tracking_integration&utm_campaign=super_gradients"><img src="https://i.ibb.co/QnyBq3p/Screen-Shot-2023-04-30-at-18-23-41.png" alt="DagsHubXSuperGradients" border="0"></a></center>
#
# <center><h3>Train SOTA models by SuperGradients with DagsHub Logger to achive full reproducibility</h3></center>
#
# ---
#
# <center><h4>Learn how to use <b>DagsHub Logger</b> callback, integrated into the SuperGradients package, to log the training parameters, metrics, data and trained model using <a href="https://mlflow.org/">MLflow</a> or <a href="https://dvc.org/">DVC</a> under the hood. </h4>
#
# <h4> <b>Achieve full reproducibility and model <-> data lineage by adding a few lines of code.<b>
# </h4><center>
#
#
#
#
# <a href="https://discord.gg/pk22NradY4" title="DagsHub on Discord"><img src="https://img.shields.io/discord/698874030052212737?logo=data%3Aimage%2Fpng%3Bbase64%2CiVBORw0KGgoAAAANSUhEUgAAAB4AAAAXCAYAAAAcP%...%%2BIDwveG1wTU06SGlzdG9yeT4gPC9yZGY6RGVzY3JpcHRpb24%2BIDwvcmRmOlJERj4gPC94OnhtcG1ldGE%2BIDw%2FeHBhY2tldCBlbmQ9InIiPz4jeahYAAACnElEQVRIx62WPWxOURjH7%2Fu%2BrTdN1RsGIkgw2BBLQwxCmvgamzAxCAs2xCYGSZWBWYihSUcDFhJpJJ1M0kUqJS1BlRCk%2Bno%2F7s%2FyPPV38lwtcZKTc%2B89z33%2B%2F%2BfznAzIkllO3lcD%2FcAloBbI%2B9wMDAB7ArlSKl8EWgWOAA%2BAWX6Ni8AaoA84AOwDdhm5%2ByL3ARgG9haBK2jF1rXAJL%2BPps2ikdvaANrJ3sMIXIE7bL1jP3w3sDxRjilv2WwX7DeAur2fM92dKbCD7hbmRZbli%2Fjmo2XrF2ClhtPN99g%2BWgD4X8YPWwfUao3tDnFT%2Fh%2BBPRQfJdtL6vebCcM0uRoLEGrbv61gzz14wq32GPcA7xOGHr92Qdz%2B9K0VEMdCmQFlB96fCKRZOgIMAd8Cxf48CdwCxgID%2FHnWynU%2Bq68GSeUKz0rJbQTeiTInOqqlYiTVkFz09SvwSCLo65go67b1tJB0r2yXkGXAKusDaq0bddmBu4BXiZUuNCx1Xklq3cl9NSCtkArwrEDnPQdeF7BzpU%2Bk6N3i44HFWxOLVxihSOdTB95SkFDO9Ki4uwZMyL4ru5scNteDZHV9U0A1s%2FhErU%2Bfh%2BxYnAqyui3euWAnGkHNu9wMUNOOFfXcZtA%2BF1PH9aD%2BtYMtz4BeAckDQeS0qssR2RJ3N4E5yRUKTiyAaaAnAzbI5lzSrW6biz%2F%2FRW9%2BCZwBHgtg23QDPNc67pOSQs7RF8ApYBtwGLhhzWICeAu8AcatFV6zW0mvkf1kRtRF7yiwyYH9SOwCrhTcNA4mWdtppbNUatfnYBD3GeCkXrGy9GYArLdymE5KpWqNpBRc9ErAElu7gdf27zhw3gi6XEd69SknBJYBx4yIesYvDj5LQsat3wkcCrw0T%2FonycbE%2FgQEhDUAAAAASUVORK5CYII%3D"></a> | <a href="https://www.youtube.com/c/DagsHub" title="DagsHub on Youtube"><img src="https://img.shields.io/youtube/channel/subscribers/UCeuZrCdpIY69XNWqn9OeSYQ?style=social"></a> | <a href="https://twitter.com/TheRealDAGsHub" title="DAGsHub on Twitter"><img src="https://img.shields.io/twitter/follow/TheRealDAGsHub.svg?style=social"></a>

# %% [markdown]
# # 🧘‍♀️ Before we start
#
# <h5><center><b>If you want to follow along this notebook and log your SuperGradients experiment to DagsHub, you will need to sign up for DagsHub (it's free!)<b></center></h5>
#
# <center><a href="https://dagshub.com/user/sign_up?utm_source=github&utm_medium=experiment_tracking_integration&utm_campaign=super_gradients" title="DAGsHub Sign Up"><img src="https://img.shields.io/badge/DagsHub-Sign%20Up-%231F4C55?logo=data:image/png;base64,..." height="25"></a>
#
# <br/>
# <br/>

# %% [markdown]
# # 🧰 Installation

# %%
# !pip install super_gradients
# !pip install dagshub mlflow --quiet
# !pip install matplotlib==3.1.3 --quiet
# !python -m pip install --upgrade pillow==9.2.0 --quiet
# !pip install --upgrade Pillow --quiet

# %% [markdown]
# # Stop & restart run time
#
# <h4><b>Importent Note: </b>The default version of `Pillow` installed on Colab is outdated and needs to be upgraded. Once you run the above cell, please restart the runtime.</h4>

# %% [markdown]
# # 🏗️ Imports

# %%
import os

import requests
import torch
from PIL import Image

from dagshub.streaming import install_hooks

from super_gradients.training import Trainer, dataloaders, models
from super_gradients.training.dataloaders.dataloaders import (
    coco_detection_yolo_format_train, coco_detection_yolo_format_val
)
# Out:
# [2023-05-07 17:15:43] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# The console stream is logged into /root/sg_logs/console.log
# [2023-05-07 17:15:51] INFO - utils.py - NumExpr defaulting to 2 threads.
# [2023-05-07 17:15:54] WARNING - __init__.py - Failed to import pytorch_quantization
# [2023-05-07 17:15:54] WARNING - calibrator.py - Failed to import pytorch_quantization
# [2023-05-07 17:15:54] WARNING - export.py - Failed to import pytorch_quantization
# [2023-05-07 17:15:54] WARNING - selective_quantization_utils.py - Failed to import pytorch_quantization
# [2023-05-07 17:15:54] INFO - env_sanity_check.py - Library check is not supported when super_gradients installed through "git+https://github.com/..." command

# %% [markdown]
# # 🎩 Set-up SuperGradients

# %% [markdown]
# ## Experiment setup
#
# We will first initialize our trainer which will be in charge of everything, like training, evaluation, saving checkpoints, plotting etc.
#
# The experiment name argument is important as every checkpoints, logs and tensorboards to be saved in a directory with the same name. This directory will be created as a sub-directory of ckpt_root_dir.

# %%
trainer = Trainer(experiment_name="pascal_voc_detectio", ckpt_root_dir="./train_models")

# %% [markdown]
# ## Dataset definition
# For the sake of this presentation, We'll use `PASCAL VOC` data set that can be found [here](http://host.robots.ox.ac.uk/pascal/VOC/).
#
# You can see the internal structure and file definition there, too.
#
# We will use [torchvision dataset implementation where SuperGradients wil handle its download for you.

# %%
from super_gradients.training import dataloaders


class_inclusion_list = ["car", "person"]
num_classes = len(class_inclusion_list)
train_dataloader = dataloaders.get(name='pascal_voc_detection_train',
                                   dataset_params={"class_inclusion_list": class_inclusion_list},
                                   dataloader_params={'num_workers': 2}
                                   )

val_dataloader = dataloaders.get(name='pascal_voc_detection_val',
                                 dataset_params={"class_inclusion_list": class_inclusion_list},
                                 dataloader_params={'num_workers': 2}
                                 )
# Out:
# [2023-05-07 17:15:54] INFO - utils.py - Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar to data/pascal_voc/images/VOCtrainval_06-Nov-2007.tar...
#   0%|          | 0.00/439M [00:00<?, ?B/s]
# [2023-05-07 17:15:58] INFO - utils.py - Extracting to data/pascal_voc/images...
# [2023-05-07 17:16:02] INFO - utils.py - Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar to data/pascal_voc/images/VOCtest_06-Nov-2007.tar...
#   0%|          | 0.00/430M [00:00<?, ?B/s]
# [2023-05-07 17:16:05] INFO - utils.py - Extracting to data/pascal_voc/images...
# [2023-05-07 17:16:08] INFO - utils.py - Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar to data/pascal_voc/images/VOCtrainval_11-May-2012.tar...
#   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# [2023-05-07 17:16:20] INFO - utils.py - Extracting to data/pascal_voc/images...
# train2012: 100%|██████████| 5717/5717 [00:01<00:00, 4131.92it/s]
# val2012: 100%|██████████| 5823/5823 [00:01<00:00, 4109.63it/s]
# train2007: 100%|██████████| 2501/2501 [00:01<00:00, 2087.29it/s]
# val2007: 100%|██████████| 2510/2510 [00:00<00:00, 2766.29it/s]
# test2007: 100%|██████████| 4952/4952 [00:01<00:00, 2602.40it/s]
# [2023-05-07 17:16:41] WARNING - detection_dataset.py - Deprecation: original_target_format should be of type ConcatenatedTensorFormat instead of DetectionTargetsFormat.Support for DetectionTargetsFormat will be removed in 3.1
# Caching annotations: 100%|██████████| 2501/2501 [00:01<00:00, 1819.30it/s]
# [2023-05-07 17:16:42] WARNING - detection_dataset.py - Deprecation: original_target_format should be of type ConcatenatedTensorFormat instead of DetectionTargetsFormat.Support for DetectionTargetsFormat will be removed in 3.1
# Caching annotations: 100%|██████████| 2510/2510 [00:01<00:00, 1685.45it/s]
# [2023-05-07 17:16:44] WARNING - detection_dataset.py - Deprecation: original_target_format should be of type ConcatenatedTensorFormat instead of DetectionTargetsFormat.Support for DetectionTargetsFormat will be removed in 3.1
# Caching annotations: 100%|██████████| 5717/5717 [00:02<00:00, 2516.95it/s]
# [2023-05-07 17:16:46] WARNING - detection_dataset.py - Deprecation: original_target_format should be of type ConcatenatedTensorFormat instead of DetectionTargetsFormat.Support for DetectionTargetsFormat will be removed in 3.1
# Caching annotations: 100%|██████████| 5823/5823 [00:02<00:00, 2565.70it/s]
# [2023-05-07 17:16:48] INFO - utils.py - Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar to data/pascal_voc/images/VOCtrainval_06-Nov-2007.tar...
#   0%|          | 0.00/439M [00:00<?, ?B/s]
# [2023-05-07 17:16:51] INFO - utils.py - Extracting to data/pascal_voc/images...
# [2023-05-07 17:16:54] INFO - utils.py - Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar to data/pascal_voc/images/VOCtest_06-Nov-2007.tar...
#   0%|          | 0.00/430M [00:00<?, ?B/s]
# [2023-05-07 17:16:56] INFO - utils.py - Extracting to data/pascal_voc/images...
# [2023-05-07 17:16:59] INFO - utils.py - Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar to data/pascal_voc/images/VOCtrainval_11-May-2012.tar...
#   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# [2023-05-07 17:17:10] INFO - utils.py - Extracting to data/pascal_voc/images...
# train2012: 100%|██████████| 5717/5717 [00:01<00:00, 2963.02it/s]
# val2012: 100%|██████████| 5823/5823 [00:02<00:00, 2725.02it/s]
# train2007: 100%|██████████| 2501/2501 [00:01<00:00, 2435.21it/s]
# val2007: 100%|██████████| 2510/2510 [00:01<00:00, 2400.49it/s]
# test2007: 100%|██████████| 4952/4952 [00:02<00:00, 2268.26it/s]
# [2023-05-07 17:17:34] WARNING - detection_dataset.py - Deprecation: original_target_format should be of type ConcatenatedTensorFormat instead of DetectionTargetsFormat.Support for DetectionTargetsFormat will be removed in 3.1
# Caching annotations:  92%|█████████▏| 4539/4952 [00:01<00:00, 2429.48it/s]

# %%
train_dataloader.dataset.datasets[0].plot()
# Out:
# Caching annotations: 100%|██████████| 4952/4952 [00:01<00:00, 2626.91it/s]

# %%
train_dataloader.dataloader_params
# Out:
# {'num_workers': 2,
#  'shuffle': True,
#  'batch_size': 16,
#  'drop_last': True,
#  'pin_memory': True,
#  'worker_init_fn': <function super_gradients.training.datasets.datasets_utils.worker_init_reset_seed(worker_id)>,
#  'collate_fn': <super_gradients.training.utils.detection_utils.DetectionCollateFN at 0x7f0e4eace3b0>}

# %%
train_dataloader.dataset.dataset_params
# Out:
# {'class_inclusion_list': ['car', 'person'],
#  'data_dir': './data/pascal_voc/',
#  'input_dim': [320, 320],
#  'cache': False,
#  'cache_dir': None,
#  'transforms': [{'DetectionPaddedRescale': {'input_dim': [320, 320]}}, {'DetectionTargetsFormatTransform': {'max_targets': 50, 'input_dim': [320, 320], 'output_format': 'LABEL_CXCYWH'}}],
#  'max_num_samples': None,
#  'download': True}

# %% [markdown]
# ## Model architecture definition
# SG includes implementations of many different architectures for classification tasks. The architecture that uses here is `yolo_nas_m`. We are going to use weights pretrained on the `coco` dataset as a starting point.

# %%
from super_gradients.training import Trainer, models
from super_gradients.training.losses import PPYoloELoss
from super_gradients.training.metrics import DetectionMetrics_050
from super_gradients.training.models.detection_models.pp_yolo_e import (
    PPYoloEPostPredictionCallback
)

# %%
model = models.get("yolo_nas_m", 
                   num_classes=len(train_dataloader.dataset.dataset_params["class_inclusion_list"]), 
                   pretrained_weights="coco"
                   )
# Out:
# [2023-05-07 17:17:40] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.
# Downloading: "https://sghub.deci.ai/models/yolo_nas_m_coco.pth" to /root/.cache/torch/hub/checkpoints/yolo_nas_m_coco.pth
#   0%|          | 0.00/196M [00:00<?, ?B/s]

# %% [markdown]
# ## Transfer learning:
# The training parameters for this use case were optimized per dataset and architecture and the type of training (from scratch\transfer learning). For more recommended training params you can have a look at [SuperGradients recipes](https://github.com/Deci-AI/super-gradients/tree/master/src/super_gradients/recipes).

# %% [markdown]
# # 🐶 Set-up DagsHub

# %% [markdown]
# ## What is the DagsHub Logger?
# DagsHub provides an out-of-the-box remote MLflow server to log experiments to, including metrics, parameters and artifacts (models, data, etc.). You can view the information under the experiment tab, share it with your team, and manage the trained models from the full-fledged MLflow UI built into your DagsHub project.
#
# With the DagsHub Logger you can log the experiment information and artifacts using MLflow by only setting a few parameters to SuperGradients's `trainer` module. On top of it, you can also version the artifact using DVC, and push them to your DagsHub storage to unlock visualisation and diffing capabilities.

# %% [markdown]
# ## How to use DagsHub Logger with SuperGradients?
# DagsHub logger is supported as a callback in SuperGradients, and can be used by adding a few parameters to the `trainer` module.
#
# 1. Set DagsHub as the trainer's logger:
#   ```
#   training_params["sg_logger"] = "dagshub_sg_logger"
#   ```
#
# 2. Provide the DagsHub repo name and owner:
#   ```
#   :param dagshub_repository: Format: <dagshub_username>/<dagshub_reponame>
#   ```
#   In the event that the repository does not exist, it will be created automatically on your behalf.

# %% [markdown]
# ## Additinal parameters
#
# ```
# :param experiment_name: Name used for logging and loading purposes
# :param storage_location: If set to 's3' (i.e. s3://my-bucket) saves the Checkpoints in AWS S3 otherwise saves the Checkpoints Locally
# :param resumed: If true, then old tensorboard files will **NOT** be deleted when tb_files_user_prompt=True
# :param training_params: training_params for the experiment.
# :param checkpoints_dir_path: Local root directory path where all experiment logging directories will reside.
# :param tb_files_user_prompt: Asks user for Tensorboard deletion prompt.
# :param launch_tensorboard: Whether to launch a TensorBoard process.
# :param tensorboard_port: Specific port number for the tensorboard to use when launched (when set to None, some free port number will be used
# :param save_checkpoints_remote: Saves checkpoints in s3 and DagsHub.
# :param save_tensorboard_remote: Saves tensorboard in s3.
# :param save_logs_remote: Saves log files in s3 and DagsHub.
# :param monitor_system: Save the system statistics (GPU utilization, CPU, ...) in the tensorboard
# :param dagshub_auth: Provide dagshub authentication token for automatic pipeline
# :param log_mlflow_only: Skip logging to DVC, use MLflow for all artifacts being logged
# ```

# %%
train_params = {
    "sg_logger": "dagshub_sg_logger",
    "sg_logger_params":  # Params that will be passes to __init__ of the logger super_gradients.common.sg_loggers.dagshub_sg_logger.DagsHubSGLogger
                     {
                       "dagshub_repository": "nirbarazida/yolonax_cifar", # Optional: Your DagsHub project name, consisting of the owner name, followed by '/', and the repo name. If this is left empty, you'll be prompted in your run to fill it in manually.
                       "log_mlflow_only": False, # Optional: Change to true to bypass logging to DVC, and log all artifacts only to MLflow  
                       "save_checkpoints_remote": True,
                       "save_tensorboard_remote": True,
                       "save_logs_remote": True,
                     },
    # ENABLING SILENT MODE
    "average_best_models":True,
    "warmup_mode": "linear_epoch_step",
    # "warmup_initial_lr": 1e-2,#1e-6,
    "lr_warmup_epochs": 3,
    "initial_lr": 1e-2,
    "lr_mode": "cosine",
    "cosine_final_lr_ratio": 0.1,
    "optimizer": "SGD",
    # "optimizer_params": {"weight_decay": 0.0001},
    "zero_weight_decay_on_bias_and_bn": True,
    "ema": True,
    "ema_params": {"decay": 0.9, "decay_type": "threshold"},
    # ONLY TRAINING FOR 10 EPOCHS FOR THIS EXAMPLE NOTEBOOK
    "max_epochs": 3,
    "mixed_precision": True,
    "loss": PPYoloELoss(
        use_static_assigner=False,
        # NOTE: num_classes needs to be defined here
        num_classes=len(train_dataloader.dataset.dataset_params["class_inclusion_list"]),
        reg_max=16
    ),
    "valid_metrics_list": [
        DetectionMetrics_050(
            score_thres=0.1,
            top_k_predictions=300,
            # NOTE: num_classes needs to be defined here
            num_cls=len(train_dataloader.dataset.dataset_params["class_inclusion_list"]),
            normalize_targets=True,
            post_prediction_callback=PPYoloEPostPredictionCallback(
                score_threshold=0.01,
                nms_top_k=1000,
                max_predictions=300,
                nms_threshold=0.7
            )
        )
    ],
    "metric_to_watch": 'mAP@0.50'
}

# %%
trainer.train(model=model, 
              training_params=train_params, 
              train_loader=train_dataloader, 
              valid_loader=val_dataloader)
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# [2023-05-07 17:36:51] INFO - sg_trainer.py - Using EMA with params {'decay': 0.9, 'decay_type': 'threshold'}
# Output()
# The console stream is now moved to ./train_models/pascal_voc_detectio/console_May07_17_36_51.txt
#
#
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=859fe37e-60bb-4644-9dec-373a75b24e02&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=ce7251da94b3822e23fa9da2301650b11316783bc6a0113e2593a2d34b11f362
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Repository initialized!
# [2023-05-07 17:36:59] INFO - helpers.py - Repository initialized!
# 2023/05/07 17:36:59 INFO mlflow.tracking.fluent: Experiment with name 'pascal_voc_detectio' does not exist. Creating a new experiment.
# [2023-05-07 17:37:22] INFO - sg_trainer_utils.py - TRAINING PARAMETERS:
#     - Mode:                         Single GPU
#     - Number of GPUs:               1          (1 available on the machine)
#     - Dataset size:                 7309       (len(train_set))
#     - Batch size per GPU:           16         (batch_size)
#     - Batch Accumulate:             1          (batch_accumulate)
#     - Total batch size:             16         (num_gpus * batch_size)
#     - Effective Batch size:         16         (num_gpus * batch_size * batch_accumulate)
#     - Iterations per epoch:         456        (len(train_loader))
#     - Gradient updates per epoch:   456        (len(train_loader) / batch_accumulate)
#
# [2023-05-07 17:37:22] INFO - sg_trainer.py - Started training for 3 epochs (0/2)
#
# Train epoch 0: 100%|██████████| 456/456 [02:52<00:00,  2.64it/s, PPYoloELoss/loss=2.26, PPYoloELoss/loss_cls=1.14, PPYoloELoss/loss_dfl=1.16, PPYoloELoss/loss_iou=0.217, gpu_mem=2.99]
# Validation epoch 0: 100%|██████████| 40/40 [00:36<00:00,  1.11it/s]
# ===========================================================
# SUMMARY OF EPOCH 0
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.2612
# │   ├── Ppyoloeloss/loss_cls = 1.1375
# │   ├── Ppyoloeloss/loss_dfl = 1.1602
# │   └── Ppyoloeloss/loss_iou = 0.2175
# └── Validation
#     ├── F1@0.50 = 0.0993
#     ├── Map@0.50 = 0.5846
#     ├── Ppyoloeloss/loss = 1.9335
#     ├── Ppyoloeloss/loss_cls = 0.9522
#     ├── Ppyoloeloss/loss_dfl = 1.0076
#     ├── Ppyoloeloss/loss_iou = 0.191
#     ├── Precision@0.50 = 0.0527
#     └── Recall@0.50 = 0.8553
#
# ===========================================================
# [2023-05-07 17:43:36] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.584586501121521
# Train epoch 1: 100%|██████████| 456/456 [02:43<00:00,  2.79it/s, PPYoloELoss/loss=2.01, PPYoloELoss/loss_cls=0.999, PPYoloELoss/loss_dfl=1.05, PPYoloELoss/loss_iou=0.195, gpu_mem=4.72]
# Validation epoch 1: 100%|██████████| 40/40 [00:36<00:00,  1.11it/s]
# ===========================================================
# SUMMARY OF EPOCH 1
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.0122
# │   │   ├── Best until now = 2.2612 (↘ -0.2491)
# │   │   └── Epoch N-1      = 2.2612 (↘ -0.2491)
# │   ├── Ppyoloeloss/loss_cls = 0.9985
# │   │   ├── Best until now = 1.1375 (↘ -0.1389)
# │   │   └── Epoch N-1      = 1.1375 (↘ -0.1389)
# │   ├── Ppyoloeloss/loss_dfl = 1.0522
# │   │   ├── Best until now = 1.1602 (↘ -0.108)
# │   │   └── Epoch N-1      = 1.1602 (↘ -0.108)
# │   └── Ppyoloeloss/loss_iou = 0.195
# │       ├── Best until now = 0.2175 (↘ -0.0225)
# │       └── Epoch N-1      = 0.2175 (↘ -0.0225)
# └── Validation
#     ├── F1@0.50 = 0.1147
#     │   ├── Best until now = 0.0993 (↗ 0.0155)
#     │   └── Epoch N-1      = 0.0993 (↗ 0.0155)
#     ├── Map@0.50 = 0.607
#     │   ├── Best until now = 0.5846 (↗ 0.0224)
#     │   └── Epoch N-1      = 0.5846 (↗ 0.0224)
#     ├── Ppyoloeloss/loss = 1.8934
#     │   ├── Best until now = 1.9335 (↘ -0.0402)
#     │   └── Epoch N-1      = 1.9335 (↘ -0.0402)
#     ├── Ppyoloeloss/loss_cls = 0.9099
#     │   ├── Best until now = 0.9522 (↘ -0.0423)
#     │   └── Epoch N-1      = 0.9522 (↘ -0.0423)
#     ├── Ppyoloeloss/loss_dfl = 1.0222
#     │   ├── Best until now = 1.0076 (↗ 0.0147)
#     │   └── Epoch N-1      = 1.0076 (↗ 0.0147)
#     ├── Ppyoloeloss/loss_iou = 0.189
#     │   ├── Best until now = 0.191  (↘ -0.0021)
#     │   └── Epoch N-1      = 0.191  (↘ -0.0021)
#     ├── Precision@0.50 = 0.0615
#     │   ├── Best until now = 0.0527 (↗ 0.0087)
#     │   └── Epoch N-1      = 0.0527 (↗ 0.0087)
#     └── Recall@0.50 = 0.8657
#         ├── Best until now = 0.8553 (↗ 0.0105)
#         └── Epoch N-1      = 0.8553 (↗ 0.0105)
#
# ===========================================================
# [2023-05-07 17:48:52] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.6069886088371277
# File already staged for upload on path
# "artifacts/./train_models/pascal_voc_detectio/experiment_logs_May07_17_36_51.txt". Overwriting
# [2023-05-07 17:50:04] INFO - helpers.py - File already staged for upload on path "artifacts/./train_models/pascal_voc_detectio/experiment_logs_May07_17_36_51.txt". Overwriting
# Train epoch 2: 100%|██████████| 456/456 [02:46<00:00,  2.73it/s, PPYoloELoss/loss=1.94, PPYoloELoss/loss_cls=0.95, PPYoloELoss/loss_dfl=1.03, PPYoloELoss/loss_iou=0.19, gpu_mem=4.72]
# Validation epoch 2: 100%|██████████| 40/40 [00:36<00:00,  1.10it/s]
# ===========================================================
# SUMMARY OF EPOCH 2
# ├── Training
# │   ├── Ppyoloeloss/loss = 1.9417
# │   │   ├── Best until now = 2.0122 (↘ -0.0704)
# │   │   └── Epoch N-1      = 2.0122 (↘ -0.0704)
# │   ├── Ppyoloeloss/loss_cls = 0.9499
# │   │   ├── Best until now = 0.9985 (↘ -0.0486)
# │   │   └── Epoch N-1      = 0.9985 (↘ -0.0486)
# │   ├── Ppyoloeloss/loss_dfl = 1.0322
# │   │   ├── Best until now = 1.0522 (↘ -0.02)
# │   │   └── Epoch N-1      = 1.0522 (↘ -0.02)
# │   └── Ppyoloeloss/loss_iou = 0.1903
# │       ├── Best until now = 0.195  (↘ -0.0047)
# │       └── Epoch N-1      = 0.195  (↘ -0.0047)
# └── Validation
#     ├── F1@0.50 = 0.1337
#     │   ├── Best until now = 0.1147 (↗ 0.0189)
#     │   └── Epoch N-1      = 0.1147 (↗ 0.0189)
#     ├── Map@0.50 = 0.6335
#     │   ├── Best until now = 0.607  (↗ 0.0265)
#     │   └── Epoch N-1      = 0.607  (↗ 0.0265)
#     ├── Ppyoloeloss/loss = 1.8808
#     │   ├── Best until now = 1.8934 (↘ -0.0125)
#     │   └── Epoch N-1      = 1.8934 (↘ -0.0125)
#     ├── Ppyoloeloss/loss_cls = 0.9078
#     │   ├── Best until now = 0.9099 (↘ -0.0021)
#     │   └── Epoch N-1      = 0.9099 (↘ -0.0021)
#     ├── Ppyoloeloss/loss_dfl = 1.0149
#     │   ├── Best until now = 1.0076 (↗ 0.0073)
#     │   └── Epoch N-1      = 1.0222 (↘ -0.0074)
#     ├── Ppyoloeloss/loss_iou = 0.1862
#     │   ├── Best until now = 0.189  (↘ -0.0027)
#     │   └── Epoch N-1      = 0.189  (↘ -0.0027)
#     ├── Precision@0.50 = 0.0727
#     │   ├── Best until now = 0.0615 (↗ 0.0112)
#     │   └── Epoch N-1      = 0.0615 (↗ 0.0112)
#     └── Recall@0.50 = 0.8578
#         ├── Best until now = 0.8657 (↘ -0.0079)
#         └── Epoch N-1      = 0.8657 (↘ -0.0079)
#
# ===========================================================
# File already staged for upload on path "models/ckpt_latest.pth". Overwriting
# [2023-05-07 17:54:13] INFO - helpers.py - File already staged for upload on path "models/ckpt_latest.pth". Overwriting
# File already staged for upload on path "models/ckpt_best.pth". Overwriting
# [2023-05-07 17:56:22] INFO - helpers.py - File already staged for upload on path "models/ckpt_best.pth". Overwriting
# [2023-05-07 17:56:22] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.6334812641143799
# File already staged for upload on path "models/average_model.pth". Overwriting
# File already staged for upload on path
# "artifacts/./train_models/pascal_voc_detectio/experiment_logs_May07_17_36_51.txt". Overwriting
# [2023-05-07 17:57:03] INFO - helpers.py - File already staged for upload on path "models/average_model.pth". Overwriting
# [2023-05-07 17:57:03] INFO - helpers.py - File already staged for upload on path "artifacts/./train_models/pascal_voc_detectio/experiment_logs_May07_17_36_51.txt". Overwriting
# [2023-05-07 17:57:03] INFO - sg_trainer.py - RUNNING ADDITIONAL TEST ON THE AVERAGED MODEL...
# Validation epoch 3: 100%|██████████| 40/40 [00:37<00:00,  1.07it/s]
# ===========================================================
# SUMMARY OF EPOCH 3
# ├── Training
# │   ├── Ppyoloeloss/loss = 1.9417
# │   │   ├── Best until now = 2.0122 (↘ -0.0704)
# │   │   └── Epoch N-1      = 2.0122 (↘ -0.0704)
# │   ├── Ppyoloeloss/loss_cls = 0.9499
# │   │   ├── Best until now = 0.9985 (↘ -0.0486)
# │   │   └── Epoch N-1      = 0.9985 (↘ -0.0486)
# │   ├── Ppyoloeloss/loss_dfl = 1.0322
# │   │   ├── Best until now = 1.0522 (↘ -0.02)
# │   │   └── Epoch N-1      = 1.0522 (↘ -0.02)
# │   └── Ppyoloeloss/loss_iou = 0.1903
# │       ├── Best until now = 0.195  (↘ -0.0047)
# │       └── Epoch N-1      = 0.195  (↘ -0.0047)
# └── Validation
#     ├── F1@0.50 = 0.2458
#     │   ├── Best until now = 0.1337 (↗ 0.1121)
#     │   └── Epoch N-1      = 0.1337 (↗ 0.1121)
#     ├── Map@0.50 = 0.7248
#     │   ├── Best until now = 0.6335 (↗ 0.0913)
#     │   └── Epoch N-1      = 0.6335 (↗ 0.0913)
#     ├── Ppyoloeloss/loss = 1.8097
#     │   ├── Best until now = 1.8808 (↘ -0.0711)
#     │   └── Epoch N-1      = 1.8808 (↘ -0.0711)
#     ├── Ppyoloeloss/loss_cls = 0.9522
#     │   ├── Best until now = 0.9078 (↗ 0.0444)
#     │   └── Epoch N-1      = 0.9078 (↗ 0.0444)
#     ├── Ppyoloeloss/loss_dfl = 0.9125
#     │   ├── Best until now = 1.0076 (↘ -0.0951)
#     │   └── Epoch N-1      = 1.0149 (↘ -0.1024)
#     ├── Ppyoloeloss/loss_iou = 0.1605
#     │   ├── Best until now = 0.1862 (↘ -0.0257)
#     │   └── Epoch N-1      = 0.1862 (↘ -0.0257)
#     ├── Precision@0.50 = 0.1432
#     │   ├── Best until now = 0.0727 (↗ 0.0705)
#     │   └── Epoch N-1      = 0.0727 (↗ 0.0705)
#     └── Recall@0.50 = 0.8724
#         ├── Best until now = 0.8657 (↗ 0.0066)
#         └── Epoch N-1      = 0.8578 (↗ 0.0145)
#
# ===========================================================
# File already staged for upload on path
# "artifacts/./train_models/pascal_voc_detectio/experiment_logs_May07_17_36_51.txt". Overwriting
# [2023-05-07 17:57:42] INFO - helpers.py - File already staged for upload on path "artifacts/./train_models/pascal_voc_detectio/experiment_logs_May07_17_36_51.txt". Overwriting
# Uploading files (4) to "nirbarazida/yolonax_cifar"...
# [2023-05-07 17:57:43] INFO - helpers.py - Uploading files (4) to "nirbarazida/yolonax_cifar"...
# Upload finished successfully!
# [2023-05-07 17:58:59] INFO - helpers.py - Upload finished successfully!

# %% [markdown]
# # 🏁 Finish line
#
# Congratulations! You've reached the finish line!
#
# You successfully logged your experiment with DagsHub. You can see the metrics and parameters under the experiment tab, the artifacts logged by MLflow unser `http://dagshub.com/<repo-owner>/<repo-name>.mlflow` and the DVC versioned files in the file view of the repo.
#
# If you have any questions, feel free to reach out on our community Discord server 👉
# <a href="https://discord.gg/pk22NradY4" title="DagsHub on Discord"><img src="https://img.shields.io/discord/698874030052212737?logo=data%3Aimage%2Fpng%3Bbase64%2CiVBORw0KGgoAAAANSUhEUgAAAB4AAAAXCAYAAAAcP%...%%2BIDwveG1wTU06SGlzdG9yeT4gPC9yZGY6RGVzY3JpcHRpb24%2BIDwvcmRmOlJERj4gPC94OnhtcG1ldGE%2BIDw%2FeHBhY2tldCBlbmQ9InIiPz4jeahYAAACnElEQVRIx62WPWxOURjH7%2Fu%2BrTdN1RsGIkgw2BBLQwxCmvgamzAxCAs2xCYGSZWBWYihSUcDFhJpJJ1M0kUqJS1BlRCk%2Bno%2F7s%2FyPPV38lwtcZKTc%2B89z33%2B%2F%2BfznAzIkllO3lcD%2FcAloBbI%2B9wMDAB7ArlSKl8EWgWOAA%2BAWX6Ni8AaoA84AOwDdhm5%2ByL3ARgG9haBK2jF1rXAJL%2BPps2ikdvaANrJ3sMIXIE7bL1jP3w3sDxRjilv2WwX7DeAur2fM92dKbCD7hbmRZbli%2Fjmo2XrF2ClhtPN99g%2BWgD4X8YPWwfUao3tDnFT%2Fh%2BBPRQfJdtL6vebCcM0uRoLEGrbv61gzz14wq32GPcA7xOGHr92Qdz%2B9K0VEMdCmQFlB96fCKRZOgIMAd8Cxf48CdwCxgID%2FHnWynU%2Bq68GSeUKz0rJbQTeiTInOqqlYiTVkFz09SvwSCLo65go67b1tJB0r2yXkGXAKusDaq0bddmBu4BXiZUuNCx1Xklq3cl9NSCtkArwrEDnPQdeF7BzpU%2Bk6N3i44HFWxOLVxihSOdTB95SkFDO9Ki4uwZMyL4ru5scNteDZHV9U0A1s%2FhErU%2Bfh%2BxYnAqyui3euWAnGkHNu9wMUNOOFfXcZtA%2BF1PH9aD%2BtYMtz4BeAckDQeS0qssR2RJ3N4E5yRUKTiyAaaAnAzbI5lzSrW6biz%2F%2FRW9%2BCZwBHgtg23QDPNc67pOSQs7RF8ApYBtwGLhhzWICeAu8AcatFV6zW0mvkf1kRtRF7yiwyYH9SOwCrhTcNA4mWdtppbNUatfnYBD3GeCkXrGy9GYArLdymE5KpWqNpBRc9ErAElu7gdf27zhw3gi6XEd69SknBJYBx4yIesYvDj5LQsat3wkcCrw0T%2FonycbE%2FgQEhDUAAAAASUVORK5CYII%3D"></a>
